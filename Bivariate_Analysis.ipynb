# %%
df =sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Scatter plot between numerical cols

# %%
from numpy import size


sns.scatterplot(x='total_bill', y='tip', data=df, hue='sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2. Barplot (numerical categorical)

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.barplot(y='age',x='pclass',data=titanic,hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.displot(titanic['fare'],kde=true,color='darkred', bins=40)

# %%
sns.barplot(y='fare',x='pclass',data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# # Boxplot (num-cat)

# %%
sns.boxenplot(x='pclass',y='age',data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
# sns.FacetGrid(titanic,hue='sex').map(sns.kdeplot,'age').add_legend()
sns.boxplot(x='sex',y='age',data=titanic ,hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# # 4. distplot

# %%
sns.displot(titanic['age'],kde=true,color='darkred', bins=40)

# %%
from matplotlib.pyplot import hist
from sympy import false


sns.distplot(titanic[titanic['survived']==0]['age'],hist=False)
sns.distplot(titanic[titanic['survived']==1]['age'],hist=False)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_3452\1651263474.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['survived']==0]['age'],hist=False)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_3452\1651263474.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # 5. heatmap (Cat-cat)

# %%
pd.crosstab(titanic['pclass'],titanic['survived'])
# Out:
# survived    0    1
# pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['pclass'],titanic['survived']))
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
titanic.groupby('pclass')['survived'].mean()*100
# Out:
# pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: survived, dtype: float64

# %%
titanic.groupby('sex')['survived'].mean()*100
# Out:
# sex
# female    74.203822
# male      18.890815
# Name: survived, dtype: float64

# %% [markdown]
# ## 6. Cluster map

# %%
sns.clustermap(pd.crosstab(titanic['parch'],titanic['survived']))

# %%
pd.crosstab(titanic['parch'],titanic['survived'])
# Out:
# survived    0    1
# parch
# 0         445  233
# 1          53   65
# 2          40   40
# 3           2    3
# 4           4    0
# 5           4    1
# 6           1    0

# %%
sns.heatmap(pd.crosstab(titanic['parch'],titanic['survived']))
# Out:
# <Axes: xlabel='survived', ylabel='parch'>

# %% [markdown]
# # 7. pairplot(num num)

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# # 8. Lineplot (NUM NUM)

# %%
flight = sns.load_dataset('flights')

# %%
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
newdf=flight.groupby('year')['passengers'].sum().reset_index()

# %%
newdf
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(x='year',y='passengers',data=newdf)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
pivot =flight.pivot_table(values='passengers',index='month',columns='year')
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_3452\3793593809.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot =flight.pivot_table(values='passengers',index='month',columns='year')

# %%
sns.heatmap(pivot)
# Out:
# <Axes: xlabel='year', ylabel='month'>
