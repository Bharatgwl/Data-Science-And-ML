# %%
df = pd.read_csv('DATA/WC_AT.csv')

# %%
df
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.displot(df['Waist'],kde=True)

# %%
sns.displot(df['AT'],kde=True)

# %%
from sklearn.model_selection import train_test_split

X = df[['Waist']]
y = df['AT']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
ypred=model.predict(X_test)

# %%
X_test
# Out:
#       Waist
# 84   108.50
# 10    71.90
# 75   100.00
# 2     81.80
# 24    82.00
# 100  106.00
# 108  108.50
# 7     83.40
# 16    75.95
# 86   111.00
# 68   105.00
# 22    79.90
# 45   107.10
# 60    77.60
# 76   103.00
# 52    85.20
# 13    79.00
# 73   100.00
# 85   104.00
# 54    78.40
# 104  100.10
# 8     63.50

# %%
ypred
# Out:
# array([160.65263299,  34.49450742, 131.35361476,  68.61924631,
#         69.30863497, 152.03527469, 160.65263299,  74.13435562,
#         48.45462788, 169.26999129, 148.58833137,  62.070054  ,
#        155.82691234,  54.14208436, 141.69444472,  80.3388536 ,
#         58.96780501, 131.35361476, 145.14138804,  56.89963901,
#        131.69830909,   5.54018352])

# %%
model.score(X_test, y_test)
# Out:
# 0.7358029576877247

# %%
model.coef_
# Out:
# array([3.44694332])

# %%
model.intercept_
# Out:
# np.float64(-213.34071738828845)

# %%
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
model.predict([[80]])
# Out:
# c:\Users\bhara\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([62.41474833])

# %%
sns.scatterplot(df)
plt.figure(figsize=(10,6))
plt.xlabel("Waist")
plt.ylabel("AT")
plt.scatter(X_train, y_train, color='red')
# plt.plot(X_train, model.fit(X_test), color='blue')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, ypred)

# %%
mae
# Out:
# 23.900652645945442

# %%
from sklearn.ensemble import RandomForestRegressor

model=RandomForestRegressor(n_estimators=100)

model.fit(X_train, y_train)

ypred=model.predict(X_test)

model.score(X_test, y_test)
# Out:
# 0.751713962008052

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, ypred)
mae
# Out:
# 24.750592543290043

# %%
mse = mean_squared_error(y_test, ypred)
mse
# Out:
# 809.2310015340238
