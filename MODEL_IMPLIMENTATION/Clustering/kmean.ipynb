# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt 
import random
centroids = [(-5,-5),(5,5),(-2.5,2.5),(2.5,-2.5)]
cluster_std = [1,1,1,1]

X,y = make_blobs(n_samples=100,n_features=2,centers=centroids,cluster_std=cluster_std,random_state=2)

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
from turtle import distance


class Kmeans:
    def __init__(self,n_clusters=2,max_iter=100):
        self.n_clusters = n_clusters
        self.max_iter = max_iter
        self.centroids = None
    def fit_predict(self,X):
        random_index = random.sample(range(0,X.shape[0]),self.n_clusters)
        self.centroids = X[random_index]
        for i in range(self.max_iter):
            ## assigning cluster
            cluster_grp = self.assign_cluster(X)
            
            ## move centeroids
            old_centroids = self.centroids
            self.centroids = self.move_centroids(X,cluster_grp)
            
            ## checck finish 
            if (old_centroids == self.centroids).all():
                break
        return cluster_grp
            
    def assign_cluster(self,X):
        cluster_group = []
        distances = []
        
        for row in X:
            for centroid in self.centroids:
                distances.append(np.sqrt(np.dot(row-centroid,row-centroid)))
            min_distance = min(distances)
            index_pos = distances.index(min_distance)
            cluster_group.append(index_pos)
            distances.clear()
        return np.array(cluster_group)
    
    def move_centroids(self,X,cluster_grp):
        new_centroid = [
        ]
        cluster_type =np.unique(cluster_grp)
        for type in cluster_type:
            new_centroid.append(X[cluster_grp==type].mean(axis=0))
        return np.array(new_centroid)

# %%
km = Kmeans(n_clusters=4,max_iter=1000)
y_mean = km.fit_predict(X)

# %%
plt.scatter(X[y_mean==0,0],X[y_mean==0,1],color='red')
plt.scatter(X[y_mean==1,0],X[y_mean==1,1],color='blue')
plt.scatter(X[y_mean==2,0],X[y_mean==2,1],color='green')
plt.scatter(X[y_mean==3,0],X[y_mean==3,1],color='yellow')
plt.show()

# %% [markdown]
# /*************  ✨ Windsurf Command ⭐  *************/
# 1. **Initialize centroids**: Randomly select `k` data points from the dataset as initial centroids.
#
# 2. **Assign clusters**: Assign each data point to the nearest centroid, forming `k` clusters based on the nearest mean.
#
# 3. **Update centroids**: Calculate the new centroids as the mean of the data points assigned to each cluster.
#
# 4. **Convergence check**: Repeat steps 2 and 3 until the centroids do not change or a maximum number of iterations is reached.
#
# 5. **Final clusters**: Once convergence is reached, the final clusters are formed, and each data point belongs to one of these clusters based on proximity to the centroid.
#
# /*******  ba4b4dd0-8313-4b54-b7f0-db7f37de881e  *******/

# %% [markdown]
# /*************  ✨ Windsurf Command ⭐  *************/
# """
# K-means clustering is a type of unsupervised machine learning algorithm that partitions the data into k clusters based on their similarities. It works by iteratively updating the centroids of the clusters and reassigning the data points to the cluster with the nearest centroid.
#
# The algorithm works as follows:
#
# 1. **Initialize centroids**: Randomly select `k` data points from the dataset as initial centroids.
#
# 2. **Assign clusters**: Assign each data point to the nearest centroid, forming `k` clusters based on the nearest mean.
#
# 3. **Update centroids**: Calculate the new centroids as the mean of the data points assigned to each cluster.
#
# 4. **Convergence check**: Repeat steps 2 and 3 until the centroids do not change or a maximum number of iterations is reached.
#
# 5. **Final clusters**: Once convergence is reached, the final clusters are formed, and each data point belongs to one of these clusters based on proximity to the centroid.
# """
# /*******  dff421e0-3935-4503-897b-a89f090b2178  *******/
