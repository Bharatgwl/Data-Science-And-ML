# %% [markdown]
# # data cleaning

# %%
import  numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("archive/data_clean.csv")
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df.tail(10)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 148         149   30.0    193.0   6.9     70     9   26  2010    70       C
# 149         150    NaN    145.0  13.2     77     9   27  2010    77      PS
# 150         151   14.0    191.0  14.3     75     9   28  2010    75       S
# 151         152   18.0    131.0   8.0     76     9   29  2010    76      PS
# 152         153   20.0    223.0  11.5     68     9   30  2010    68       S
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (158, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
sns.boxplot(df[['Unnamed: 0','Ozone']])
# Out:
# <Axes: >

# %%
df=df.iloc[:,1:]
df
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df2 = df.copy()

# %%
df2['Month']=pd.to_numeric(df['Month'],errors='coerce')
df2['Temp C']=pd.to_numeric(df['Temp'],errors='coerce')# coerce will introduce NA values for non numeric data in the columns
df2['Weather']=df['Weather'].astype('category')

# %%
df2.head()
# Out:
#    Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4      67    5.0    1  2010    67       S
# 1   36.0    118.0   8.0      72    5.0    2  2010    72       C
# 2   12.0    149.0  12.6      74    5.0    3  2010    74      PS
# 3   18.0    313.0  11.5      62    5.0    4  2010    62       S
# 4    NaN      NaN  14.3      56    5.0    5  2010    56       S

# %%
df2
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      67    5.0    1  2010    67       S
# 1     36.0    118.0   8.0      72    5.0    2  2010    72       C
# 2     12.0    149.0  12.6      74    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5      62    5.0    4  2010    62       S
# 4      NaN      NaN  14.3      56    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4      67    5.0    1  2010    67       C
# 154   30.0    193.0   6.9      70    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2      77    9.0   27  2010    77       S
# 156   14.0    191.0  14.3      75    9.0   28  2010    75       S
# 157   18.0    131.0   8.0      76    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    int64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    category
# dtypes: category(1), float64(4), int64(4)
# memory usage: 10.3 KB

# %%
df.isnull().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Temp C      0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
# df['Ozone'].fillna((df['Ozone'].mean()),inplace=True)
df.fillna({'Ozone': df['Ozone'].mean()}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
df
# Out:
#          Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    41.000000    190.0   7.4     67     5    1  2010    67       S
# 1    36.000000    118.0   8.0     72     5    2  2010    72       C
# 2    12.000000    149.0  12.6     74     5    3  2010    74      PS
# 3    18.000000    313.0  11.5     62     5    4  2010    62       S
# 4    41.583333      NaN  14.3     56     5    5  2010    56       S
# ..         ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153  41.000000    190.0   7.4     67     5    1  2010    67       C
# 154  30.000000    193.0   6.9     70     9   26  2010    70      PS
# 155  41.583333    145.0  13.2     77     9   27  2010    77       S
# 156  14.000000    191.0  14.3     75     9   28  2010    75       S
# 157  18.000000    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df['Month']=pd.to_numeric(df['Month'],errors='coerce')
df['Temp C']=pd.to_numeric(df['Temp'],errors='coerce')# coerce will introduce NA values for non numeric data in the columns
df['Weather']=df['Weather'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    int64
#  5   Month       157 non-null    float64
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    category
# dtypes: category(1), float64(4), int64(5)
# memory usage: 11.5 KB

# %%
sns.histplot(df[ 'Weather'])
# Out:
# <Axes: xlabel='Weather', ylabel='Count'>

# %%
df.corr(numeric_only=True,method='spearman')
# Out:
#             Unnamed: 0     Ozone   Solar.R      Wind    Temp C     Month  \
# Unnamed: 0    1.000000  0.087266 -0.161775 -0.141580  0.280566  0.949968
# Ozone         0.087266  1.000000  0.354195 -0.586181  0.758121  0.104289
# Solar.R      -0.161775  0.354195  1.000000 -0.004917  0.212248 -0.142273
# Wind         -0.141580 -0.586181 -0.004917  1.000000 -0.425148 -0.129267
# Temp C        0.280566  0.758121  0.212248 -0.425148  1.000000  0.334604
# Month         0.949968  0.104289 -0.142273 -0.129267  0.334604  1.000000
# Day           0.216616 -0.075922 -0.154105  0.047229 -0.147853  0.061292
# Year               NaN       NaN       NaN       NaN       NaN       NaN
# Temp          0.280566  0.758121  0.212248 -0.425148  1.000000  0.334604
#
#                  Day  Year      Temp
# Unnamed: 0  0.216616   NaN  0.280566
# Ozone      -0.075922   NaN  0.758121
# Solar.R    -0.154105   NaN  0.212248
# Wind        0.047229   NaN -0.425148
# Temp C     -0.147853   NaN  1.000000
# ...

# %%
sns.heatmap(df.corr(numeric_only=True,method='spearman'))
# Out:
# <Axes: >
