# %%
df = pd.read_csv("DATA/Top_rated_series.csv")

# %%
df
# Out:
#      first_air_date origin_country original_language               name  \
# 0        2021-09-03             US                en  The D'Amelio Show
# 1        2008-01-20             US                en       Breaking Bad
# 2        2021-11-06             US                en             Arcane
# 3        2013-12-02             US                en     Rick and Morty
# 4        2022-04-14             US                en    The Kardashians
# ...             ...            ...               ...                ...
# 2612     2002-06-11             US                en      American Idol
# 2613     2000-07-05             US                en        Big Brother
# 2614     1997-03-31             GB                en        Teletubbies
# 2615     1985-02-19             GB                en         EastEnders
# 2616     2006-10-09             CA                fr             La Job
#
#       popularity  vote_average  vote_count  \
# 0         30.104           9.0        3071
# ...

# %%
regional_lang = df.loc[(df['original_language'] == 'en')]

# %%
regional_lang
# Out:
#      first_air_date origin_country original_language  \
# 0        2021-09-03             US                en
# 1        2008-01-20             US                en
# 2        2021-11-06             US                en
# 3        2013-12-02             US                en
# 4        2022-04-14             US                en
# ...             ...            ...               ...
# 2611     2003-05-20             US                en
# 2612     2002-06-11             US                en
# 2613     2000-07-05             US                en
# 2614     1997-03-31             GB                en
# 2615     1985-02-19             GB                en
#
#                           name  popularity  vote_average  vote_count  \
# 0            The D'Amelio Show      30.104           9.0        3071
# 1                 Breaking Bad     468.253           8.8       10131
# 2                       Arcane      95.667           8.7        2615
# ...

# %%
x = regional_lang[['name','popularity']].sort_values('popularity',ascending=False)

# %%
# sns.barplot(x.name[0:6],x.popularity[0:6])
fig = plt.figure(figsize=(12,6))
sns.barplot(x='popularity',y='name', data=x.head(6))
# Out:
# <Axes: xlabel='popularity', ylabel='name'>
